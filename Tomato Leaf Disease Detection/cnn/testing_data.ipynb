# %%
import numpy as np
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# ##Test set Image Processing

# %% [markdown]
# ##Loading Model

# %%
cnn = tf.keras.models.load_model('best_model.h5')

# %% [markdown]
# ##Visualising and Performing Prediction on Single image

# %%
#Test Image Visualization
import cv2
image_path = r"C:\Users\ramesh\Desktop\mainproject\crop disease\object detection\resized_tomato.jpg"
# Reading an image in default mode
img = cv2.imread(image_path)
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB) #Converting BGR to RGB
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %% [markdown]
# ##Testing Model

# %%
image = tf.keras.preprocessing.image.load_img(image_path,target_size=(256,256))
input_arr = tf.keras.preprocessing.image.img_to_array(image)
input_arr = np.array([input_arr])  # Convert single image to a batch.
predictions = cnn.predict(input_arr)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
print(predictions)
# Out:
# [[3.0239340e-07 1.1589729e-05 4.8822232e-05 1.4987801e-01 8.4993184e-01
#   1.0712928e-04 3.6313685e-09 4.9748616e-07 9.0617999e-11 2.0659980e-05
#   1.1206341e-06]]

# %%
result_index = np.argmax(predictions) #Return index of max element
print(result_index)
# Out:
# 4

# %%
# Displaying the image
plt.imshow(img)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
class_names
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 class_names
#
# NameError: name 'class_names' is not defined

# %%
#Single image Prediction
class_names=['Background_without_leaves', 'Tomato___Bacterial_spot', 'Tomato___Early_blight',  'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Tomato_mosaic_virus','Tomato___healthy']
print("It's a {}".format(class_names[result_index]))
# Out:
# It's a Tomato___Leaf_Mold

# %%
#bacteria,
